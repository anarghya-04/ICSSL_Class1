# %% [markdown]
# <a href="https://colab.research.google.com/github/anarghya-04/ICSSL/blob/main/ICSSL0_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt #Matplotlib for plots and graphs.

# %% [markdown]
# Class CSSL

# %%
ad_exp = [20,10,50,30]
sales = [500,400,900,750]
plt.plot(ad_exp, sales) #plotting the above using imported package.
